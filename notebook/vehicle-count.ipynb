# %%
# !pip install ultralytics -q

# %%
# !pip install deep-sort-realtime -q

# %%
# Disable warnings in the notebook to maintain clean output cells
import warnings
warnings.filterwarnings('ignore')

# Import necessary libraries
import os
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import yaml
from PIL import Image
from ultralytics import YOLO
from IPython.display import Video
from deep_sort_realtime.deepsort_tracker import DeepSort

# %%
# Fungsi untuk melacak dan menghitung kendaraan berdasarkan jenisnya
def track_and_count_vehicles(frame, detections, tracker, totalCount, class_name, gates, limits):
    # Gunakan DeepSORT untuk melacak objek berdasarkan deteksi YOLOv8
    tracks = tracker.update_tracks(detections, frame=frame)
    
    # List untuk menyimpan bounding box
    bboxes = []
    
    # Loop untuk menggambar bounding boxes dan ID objek pada frame
    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id
        ltrb = track.to_ltrb()  # bounding box format (left, top, right, bottom)
        x1, y1, x2, y2 = map(int, ltrb)
        w, h = x2 - x1, y2 - y1
        cx, cy = x1 + w // 2, y1 + h // 2

        # Simpan bounding box dan track_id untuk visualisasi di luar
        bboxes.append((x1, y1, x2, y2, track_id))
        
        # Update deteksi kendaraan yang melewati gerbang
        for i, gate in enumerate(gates, start=1):
            # Cek apakah kendaraan berada dalam batas gerbang
            if gate[0] < cx < gate[2] and gate[1] - 15 < cy < gate[1] + 15:
                # Jika kendaraan belum ada dalam daftar, tambahkan
                if totalCount.count(track_id) == 0:
                    totalCount.append(track_id)
                    cv2.line(frame, (limits[0], limits[1]), (limits[2], limits[3]), (255, 0, 255), 5)

    # Kembalikan bounding box dan totalCount
    return bboxes, totalCount

# %%
import cv2
import pandas as pd
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort

# Inisialisasi YOLOv8 model
model = YOLO("yolov8x.pt")

# Video input
video_path = "/kaggle/working/sample_video.mp4"
cap = cv2.VideoCapture(video_path)

# Dapatkan dimensi video
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))

# Definisikan VideoWriter untuk menyimpan video dalam format .avi
fourcc = cv2.VideoWriter_fourcc(*'MJPG')
out = cv2.VideoWriter('result_video.avi', fourcc, 30, (width, height))

# Membaca class names dari file
with open('/kaggle/input/classes/classes.txt', 'r') as f:
    classNames = f.read().splitlines()

# Definisikan batas gerbang
limits = [17, 151, 568, 284]

# Variabel untuk menyimpan total kendaraan yang terdeteksi
totalCount_car = []
totalCount_bus = []
totalCount_truck = []

# Definisikan posisi gerbang
gates = [[14, 157, 74, 174],
    [74, 174, 138, 190],
    [138, 190, 203, 203],
    [203, 203, 271, 218],
    [271, 218, 339, 232],
    [411, 248, 485, 264],
    [485, 264, 561, 284]]
 # Gunakan DeepSORT untuk melacak objek berdasarkan deteksi YOLOv8
tracker_car = DeepSort(max_age=30, n_init=1, max_iou_distance=0.9)
tracker_bus = DeepSort(max_age=30, n_init=1, max_iou_distance=0.9)
tracker_truck = DeepSort(max_age=30, n_init=1, max_iou_distance=0.9)

# Loop utama untuk membaca frame dan memprosesnya
frame_num = 0
while True:
    ret, frame = cap.read()
    
    if not ret:
        break
    
    frame_num += 1
    
    # Deteksi objek menggunakan YOLOv8
    results = model(frame, conf=0.8)

    # Ekstraksi bounding boxes dan skor dari hasil YOLOv8
    detections_car = []
    detections_bus = []
    detections_truck = []
    for r in results:
        for box in r.boxes:
            x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            conf = box.conf[0].cpu().numpy()
            class_id = int(box.cls[0].cpu().numpy())
            currentClasses = classNames[class_id]
            if currentClasses == 'car':
                detections_car.append(([x1, y1, (x2-x1), (y2-y1)], conf, class_id))
            if currentClasses == 'bus':
                detections_bus.append(([x1, y1, (x2-x1), (y2-y1)], conf, class_id))
            if currentClasses == 'truck':
                detections_truck.append(([x1, y1, (x2-x1), (y2-y1)], conf, class_id))
    
    # Gambar garis batas pada frame
    cv2.line(frame, (limits[0], limits[1]), (limits[2], limits[3]), (0, 0, 255), 5)
        
        # Hitung mobil
    bboxes_car, totalCount_car = track_and_count_vehicles(frame, detections_car, tracker_car, totalCount_car, 'car', gates, limits)
    print(bboxes_car)
    # Hitung bus
    bboxes_bus, totalCount_bus = track_and_count_vehicles(frame, detections_bus, tracker_bus, totalCount_bus, 'bus', gates, limits)

    # Hitung truk
    bboxes_truck, totalCount_truck = track_and_count_vehicles(frame, detections_truck, tracker_truck, totalCount_truck, 'truck', gates, limits)

    # Visualisasi bounding box dan informasi di luar fungsi
    for (x1, y1, x2, y2, track_id) in bboxes_car:
        cv2.circle(frame, ((x1 + x2) // 2, (y1 + y2) // 2), 5, (255, 0, 255), 2)
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, f'ID: {track_id} car', (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (255, 255, 255), 2)

    for (x1, y1, x2, y2, track_id) in bboxes_bus:
        cv2.circle(frame, ((x1 + x2) // 2, (y1 + y2) // 2), 5, (255, 0, 255), 2)
        cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
        cv2.putText(frame, f'ID: {track_id} bus', (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (255, 255, 255), 2)

    for (x1, y1, x2, y2, track_id) in bboxes_truck:
        cv2.circle(frame, ((x1 + x2) // 2, (y1 + y2) // 2), 5, (255, 0, 255), 2)
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 2)
        cv2.putText(frame, f'ID: {track_id} truck', (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (255, 255, 255), 2)
    
    totalVehicles = len(totalCount_car)+len(totalCount_bus)+len(totalCount_truck)
    # Tampilkan jumlah kendaraan yang telah dihitung
    cv2.putText(frame, f'Total Vehicles: {totalVehicles}', (50, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 0), 2)
    cv2.putText(frame, f'Car: {len(totalCount_car)}', (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 0), 2)
    cv2.putText(frame, f'Bus: {len(totalCount_bus)}', (50, 70), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 0), 2)
    cv2.putText(frame, f'Truck: {len(totalCount_truck)}', (50, 90), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 0), 2)

    # Simpan frame ke video output
    out.write(frame)

# Tutup video capture dan jendela OpenCV
cap.release()
out.release()
# Out:
# 0: 384x640 1 bus, 62.9ms
# Speed: 2.1ms preprocess, 62.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# []
#
# 0: 384x640 1 bus, 61.6ms
# Speed: 2.7ms preprocess, 61.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# []
# Detected bus: ID=1, BBox=(225, 111, 343, 173)
#
# 0: 384x640 1 bus, 34.4ms
# Speed: 2.3ms preprocess, 34.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# []
# Detected bus: ID=1, BBox=(225, 111, 343, 173)
#
# 0: 384x640 1 bus, 34.5ms
# Speed: 1.9ms preprocess, 34.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# []
# Detected bus: ID=1, BBox=(225, 111, 343, 173)
#
# 0: 384x640 1 bus, 34.3ms
# Speed: 1.9ms preprocess, 34.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# []
# Detected bus: ID=1, BBox=(225, 111, 343, 173)
#
# 0: 384x640 1 bus, 30.1ms
# Speed: 1.8ms preprocess, 30.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# []
# Detected bus: ID=1, BBox=(225, 111, 343, 173)
#
# 0: 384x640 1 bus, 30.6ms
# Speed: 3.8ms preprocess, 30.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# []
# Detected bus: ID=1, BBox=(225, 111, 344, 173)
#
# 0: 384x640 1 bus, 28.7ms
# Speed: 3.5ms preprocess, 28.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# []
# Detected bus: ID=1, BBox=(225, 111, 344, 173)
#
# 0: 384x640 1 car, 1 bus, 29.1ms
# Speed: 3.6ms preprocess, 29.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# []
# Detected bus: ID=1, BBox=(225, 111, 344, 173)
#
# 0: 384x640 1 car, 1 bus, 28.9ms
# Speed: 3.5ms preprocess, 28.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(132, 277, 237, 332)
# [(132, 277, 237, 332, '1')]
# Detected bus: ID=1, BBox=(226, 111, 344, 173)
#
# 0: 384x640 1 car, 1 bus, 29.4ms
# Speed: 3.7ms preprocess, 29.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(141, 276, 244, 330)
# [(141, 276, 244, 330, '1')]
# Detected bus: ID=1, BBox=(226, 111, 344, 173)
#
# 0: 384x640 1 car, 1 bus, 28.6ms
# Speed: 3.7ms preprocess, 28.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(149, 272, 254, 328)
# [(149, 272, 254, 328, '1')]
# Detected bus: ID=1, BBox=(226, 111, 345, 173)
#
# 0: 384x640 1 car, 29.7ms
# Speed: 3.7ms preprocess, 29.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(157, 270, 263, 326)
# [(157, 270, 263, 326, '1')]
# Detected bus: ID=1, BBox=(226, 111, 345, 173)
#
# 0: 384x640 1 car, 28.9ms
# Speed: 3.6ms preprocess, 28.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(166, 268, 271, 324)
# [(166, 268, 271, 324, '1')]
# Detected bus: ID=1, BBox=(226, 111, 345, 173)
#
# 0: 384x640 1 car, 30.8ms
# Speed: 1.9ms preprocess, 30.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(175, 267, 280, 322)
# [(175, 267, 280, 322, '1')]
# Detected bus: ID=1, BBox=(227, 111, 345, 173)
#
# 0: 384x640 (no detections), 30.1ms
# Speed: 3.6ms preprocess, 30.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(182, 265, 287, 320)
# [(182, 265, 287, 320, '1')]
# Detected bus: ID=1, BBox=(227, 111, 345, 173)
#
# 0: 384x640 1 car, 30.4ms
# Speed: 3.8ms preprocess, 30.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(193, 263, 296, 318)
# [(193, 263, 296, 318, '1')]
# Detected bus: ID=1, BBox=(227, 111, 345, 173)
#
# 0: 384x640 1 car, 29.1ms
# Speed: 3.8ms preprocess, 29.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(202, 262, 304, 316)
# [(202, 262, 304, 316, '1')]
# Detected bus: ID=1, BBox=(227, 111, 345, 173)
#
# 0: 384x640 1 bus, 29.9ms
# Speed: 3.7ms preprocess, 29.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(210, 260, 312, 314)
# [(210, 260, 312, 314, '1')]
# Detected bus: ID=1, BBox=(229, 110, 346, 172)
#
# 0: 384x640 (no detections), 29.6ms
# Speed: 4.1ms preprocess, 29.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(218, 258, 319, 312)
# [(218, 258, 319, 312, '1')]
# Detected bus: ID=1, BBox=(229, 109, 346, 171)
#
# 0: 384x640 (no detections), 31.7ms
# Speed: 3.6ms preprocess, 31.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(226, 256, 327, 310)
# [(226, 256, 327, 310, '1')]
# Detected bus: ID=1, BBox=(229, 109, 347, 171)
#
# 0: 384x640 (no detections), 31.5ms
# Speed: 2.6ms preprocess, 31.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(233, 255, 335, 308)
# [(233, 255, 335, 308, '1')]
# Detected bus: ID=1, BBox=(229, 109, 347, 171)
#
# 0: 384x640 (no detections), 32.8ms
# Speed: 2.5ms preprocess, 32.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(241, 253, 343, 306)
# [(241, 253, 343, 306, '1')]
# Detected bus: ID=1, BBox=(230, 109, 347, 171)
#
# 0: 384x640 (no detections), 33.7ms
# Speed: 2.5ms preprocess, 33.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(249, 251, 350, 304)
# [(249, 251, 350, 304, '1')]
# Detected bus: ID=1, BBox=(230, 109, 347, 171)
#
# 0: 384x640 (no detections), 32.8ms
# Speed: 1.9ms preprocess, 32.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(257, 249, 358, 303)
# [(257, 249, 358, 303, '1')]
# Detected bus: ID=1, BBox=(230, 109, 348, 171)
#
# 0: 384x640 (no detections), 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(265, 248, 366, 301)
# [(265, 248, 366, 301, '1')]
# Detected bus: ID=1, BBox=(230, 109, 348, 171)
#
# 0: 384x640 (no detections), 32.2ms
# Speed: 2.5ms preprocess, 32.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(273, 246, 373, 299)
# [(273, 246, 373, 299, '1')]
# Detected bus: ID=1, BBox=(231, 109, 348, 171)
#
# 0: 384x640 (no detections), 33.1ms
# Speed: 1.9ms preprocess, 33.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(281, 244, 381, 297)
# [(281, 244, 381, 297, '1')]
# Detected bus: ID=1, BBox=(231, 109, 348, 171)
#
# 0: 384x640 (no detections), 34.5ms
# Speed: 2.6ms preprocess, 34.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(289, 242, 389, 295)
# [(289, 242, 389, 295, '1')]
# Detected bus: ID=1, BBox=(231, 109, 349, 171)
#
# 0: 384x640 (no detections), 32.1ms
# Speed: 2.8ms preprocess, 32.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(297, 241, 397, 293)
# [(297, 241, 397, 293, '1')]
# Detected bus: ID=1, BBox=(231, 109, 349, 171)
#
# 0: 384x640 (no detections), 34.4ms
# Speed: 1.7ms preprocess, 34.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(305, 239, 404, 291)
# [(305, 239, 404, 291, '1')]
# Detected bus: ID=1, BBox=(232, 109, 349, 171)
#
# 0: 384x640 (no detections), 32.9ms
# Speed: 1.9ms preprocess, 32.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(313, 237, 412, 290)
# [(313, 237, 412, 290, '1')]
# Detected bus: ID=1, BBox=(232, 108, 349, 170)
#
# 0: 384x640 (no detections), 32.6ms
# Speed: 1.8ms preprocess, 32.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(321, 235, 420, 288)
# [(321, 235, 420, 288, '1')]
# Detected bus: ID=1, BBox=(232, 108, 350, 170)
#
# 0: 384x640 (no detections), 34.1ms
# Speed: 1.8ms preprocess, 34.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(329, 234, 427, 286)
# [(329, 234, 427, 286, '1')]
# Detected bus: ID=1, BBox=(232, 108, 350, 170)
#
# 0: 384x640 (no detections), 32.5ms
# Speed: 2.4ms preprocess, 32.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(337, 232, 435, 284)
# [(337, 232, 435, 284, '1')]
# Detected bus: ID=1, BBox=(232, 108, 350, 170)
#
# 0: 384x640 (no detections), 32.6ms
# Speed: 1.7ms preprocess, 32.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(345, 230, 443, 282)
# [(345, 230, 443, 282, '1')]
# Detected bus: ID=1, BBox=(233, 108, 350, 170)
#
# 0: 384x640 (no detections), 34.1ms
# Speed: 1.7ms preprocess, 34.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(353, 229, 451, 280)
# [(353, 229, 451, 280, '1')]
# Detected bus: ID=1, BBox=(233, 108, 350, 170)
#
# 0: 384x640 (no detections), 33.5ms
# Speed: 1.8ms preprocess, 33.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(361, 227, 458, 278)
# [(361, 227, 458, 278, '1')]
# Detected bus: ID=1, BBox=(233, 108, 351, 170)
#
# 0: 384x640 (no detections), 33.4ms
# Speed: 1.9ms preprocess, 33.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(369, 225, 466, 276)
# [(369, 225, 466, 276, '1')]
# Detected bus: ID=1, BBox=(233, 108, 351, 170)
#
# 0: 384x640 (no detections), 33.6ms
# Speed: 2.0ms preprocess, 33.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(377, 223, 474, 275)
# [(377, 223, 474, 275, '1')]
# Detected bus: ID=1, BBox=(234, 108, 351, 170)
#
# 0: 384x640 1 car, 33.9ms
# Speed: 1.7ms preprocess, 33.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(385, 222, 482, 273)
# [(385, 222, 482, 273, '1')]
# Detected bus: ID=1, BBox=(234, 108, 351, 170)
#
# 0: 384x640 1 car, 30.7ms
# Speed: 3.6ms preprocess, 30.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(393, 220, 489, 271)
# Detected car: ID=2, BBox=(114, 296, 214, 334)
# [(393, 220, 489, 271, '1'), (114, 296, 214, 334, '2')]
# Detected bus: ID=1, BBox=(234, 108, 352, 170)
#
# 0: 384x640 1 car, 28.9ms
# Speed: 3.6ms preprocess, 28.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(401, 218, 497, 269)
# Detected car: ID=2, BBox=(119, 294, 223, 334)
# [(401, 218, 497, 269, '1'), (119, 294, 223, 334, '2')]
# Detected bus: ID=1, BBox=(234, 108, 352, 170)
#
# 0: 384x640 1 car, 29.5ms
# Speed: 3.7ms preprocess, 29.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(409, 216, 505, 267)
# Detected car: ID=2, BBox=(126, 292, 233, 334)
# [(409, 216, 505, 267, '1'), (126, 292, 233, 334, '2')]
# Detected bus: ID=1, BBox=(235, 108, 352, 170)
#
# 0: 384x640 1 car, 29.8ms
# Speed: 4.0ms preprocess, 29.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(417, 215, 512, 265)
# Detected car: ID=2, BBox=(136, 290, 241, 332)
# [(417, 215, 512, 265, '1'), (136, 290, 241, 332, '2')]
# Detected bus: ID=1, BBox=(235, 107, 352, 169)
#
# 0: 384x640 1 car, 29.9ms
# Speed: 3.9ms preprocess, 29.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(425, 213, 520, 263)
# Detected car: ID=2, BBox=(145, 289, 249, 330)
# [(425, 213, 520, 263, '1'), (145, 289, 249, 330, '2')]
# Detected bus: ID=1, BBox=(235, 107, 353, 169)
#
# 0: 384x640 1 car, 29.0ms
# Speed: 3.5ms preprocess, 29.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(433, 211, 528, 262)
# Detected car: ID=2, BBox=(154, 287, 256, 328)
# [(433, 211, 528, 262, '1'), (154, 287, 256, 328, '2')]
# Detected bus: ID=1, BBox=(235, 107, 353, 169)
#
# 0: 384x640 1 car, 29.9ms
# Speed: 3.7ms preprocess, 29.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=1, BBox=(440, 209, 536, 260)
# Detected car: ID=2, BBox=(162, 284, 266, 326)
# [(440, 209, 536, 260, '1'), (162, 284, 266, 326, '2')]
# Detected bus: ID=1, BBox=(236, 107, 353, 169)
#
# 0: 384x640 1 car, 29.3ms
# Speed: 3.7ms preprocess, 29.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(170, 282, 274, 324)
# [(170, 282, 274, 324, '2')]
# Detected bus: ID=1, BBox=(236, 107, 353, 169)
#
# 0: 384x640 1 car, 29.1ms
# Speed: 3.7ms preprocess, 29.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(181, 280, 281, 321)
# [(181, 280, 281, 321, '2')]
#
# 0: 384x640 1 car, 29.0ms
# Speed: 3.5ms preprocess, 29.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(190, 279, 289, 320)
# [(190, 279, 289, 320, '2')]
#
# 0: 384x640 1 car, 29.7ms
# Speed: 3.6ms preprocess, 29.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(198, 276, 298, 318)
# [(198, 276, 298, 318, '2')]
#
# 0: 384x640 1 car, 29.7ms
# Speed: 3.4ms preprocess, 29.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(206, 274, 303, 315)
# [(206, 274, 303, 315, '2')]
#
# 0: 384x640 1 car, 30.0ms
# Speed: 3.4ms preprocess, 30.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(216, 272, 311, 313)
# [(216, 272, 311, 313, '2')]
#
# 0: 384x640 1 car, 29.9ms
# Speed: 4.0ms preprocess, 29.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(225, 271, 319, 311)
# [(225, 271, 319, 311, '2')]
#
# 0: 384x640 1 car, 29.2ms
# Speed: 3.4ms preprocess, 29.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(233, 268, 329, 309)
# [(233, 268, 329, 309, '2')]
#
# 0: 384x640 1 car, 29.1ms
# Speed: 3.8ms preprocess, 29.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(241, 266, 337, 307)
# [(241, 266, 337, 307, '2')]
#
# 0: 384x640 1 car, 29.1ms
# Speed: 3.6ms preprocess, 29.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(251, 264, 343, 305)
# [(251, 264, 343, 305, '2')]
#
# 0: 384x640 1 car, 29.5ms
# Speed: 3.6ms preprocess, 29.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(258, 263, 349, 303)
# [(258, 263, 349, 303, '2')]
#
# 0: 384x640 1 car, 30.1ms
# Speed: 3.7ms preprocess, 30.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(267, 261, 357, 302)
# [(267, 261, 357, 302, '2')]
#
# 0: 384x640 1 car, 30.0ms
# Speed: 3.9ms preprocess, 30.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(275, 260, 365, 300)
# [(275, 260, 365, 300, '2')]
#
# 0: 384x640 1 car, 29.5ms
# Speed: 3.3ms preprocess, 29.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(284, 258, 372, 297)
# [(284, 258, 372, 297, '2')]
#
# 0: 384x640 1 car, 29.0ms
# Speed: 3.7ms preprocess, 29.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(291, 256, 380, 295)
# [(291, 256, 380, 295, '2')]
#
# 0: 384x640 1 car, 29.3ms
# Speed: 3.6ms preprocess, 29.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(299, 254, 388, 293)
# [(299, 254, 388, 293, '2')]
#
# 0: 384x640 1 car, 30.0ms
# Speed: 3.8ms preprocess, 30.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(309, 252, 395, 291)
# [(309, 252, 395, 291, '2')]
#
# 0: 384x640 1 car, 30.2ms
# Speed: 3.6ms preprocess, 30.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(318, 251, 403, 289)
# [(318, 251, 403, 289, '2')]
#
# 0: 384x640 1 car, 29.0ms
# Speed: 3.6ms preprocess, 29.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(326, 249, 411, 287)
# [(326, 249, 411, 287, '2')]
#
# 0: 384x640 1 car, 29.0ms
# Speed: 3.6ms preprocess, 29.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(335, 248, 418, 286)
# [(335, 248, 418, 286, '2')]
#
# 0: 384x640 1 car, 29.4ms
# Speed: 3.9ms preprocess, 29.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(341, 246, 427, 284)
# [(341, 246, 427, 284, '2')]
#
# 0: 384x640 (no detections), 31.3ms
# Speed: 3.5ms preprocess, 31.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(349, 244, 434, 282)
# [(349, 244, 434, 282, '2')]
#
# 0: 384x640 (no detections), 31.2ms
# Speed: 3.8ms preprocess, 31.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(357, 242, 442, 281)
# [(357, 242, 442, 281, '2')]
#
# 0: 384x640 1 car, 31.2ms
# Speed: 2.7ms preprocess, 31.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(365, 241, 450, 279)
# [(365, 241, 450, 279, '2')]
#
# 0: 384x640 1 car, 30.6ms
# Speed: 4.2ms preprocess, 30.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(373, 239, 458, 277)
# Detected car: ID=3, BBox=(374, 241, 455, 277)
# [(373, 239, 458, 277, '2'), (374, 241, 455, 277, '3')]
#
# 0: 384x640 1 car, 29.2ms
# Speed: 3.6ms preprocess, 29.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(381, 237, 466, 275)
# Detected car: ID=3, BBox=(376, 235, 466, 275)
# [(381, 237, 466, 275, '2'), (376, 235, 466, 275, '3')]
#
# 0: 384x640 (no detections), 29.1ms
# Speed: 3.7ms preprocess, 29.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(389, 235, 474, 273)
# Detected car: ID=3, BBox=(379, 232, 471, 274)
# [(389, 235, 474, 273, '2'), (379, 232, 471, 274, '3')]
#
# 0: 384x640 (no detections), 32.7ms
# Speed: 1.8ms preprocess, 32.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(397, 234, 482, 271)
# Detected car: ID=3, BBox=(381, 230, 477, 273)
# [(397, 234, 482, 271, '2'), (381, 230, 477, 273, '3')]
#
# 0: 384x640 (no detections), 33.0ms
# Speed: 2.6ms preprocess, 33.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(405, 232, 489, 269)
# Detected car: ID=3, BBox=(383, 228, 482, 272)
# [(405, 232, 489, 269, '2'), (383, 228, 482, 272, '3')]
#
# 0: 384x640 (no detections), 34.9ms
# Speed: 1.9ms preprocess, 34.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(414, 230, 497, 268)
# Detected car: ID=3, BBox=(385, 225, 488, 271)
# [(414, 230, 497, 268, '2'), (385, 225, 488, 271, '3')]
#
# 0: 384x640 (no detections), 33.2ms
# Speed: 1.9ms preprocess, 33.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(422, 228, 505, 266)
# Detected car: ID=3, BBox=(388, 223, 493, 270)
# [(422, 228, 505, 266, '2'), (388, 223, 493, 270, '3')]
#
# 0: 384x640 1 car, 33.5ms
# Speed: 1.9ms preprocess, 33.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(430, 227, 513, 264)
# Detected car: ID=3, BBox=(390, 220, 499, 269)
# [(430, 227, 513, 264, '2'), (390, 220, 499, 269, '3')]
#
# 0: 384x640 1 car, 30.6ms
# Speed: 3.8ms preprocess, 30.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(438, 225, 521, 262)
# Detected car: ID=3, BBox=(392, 218, 504, 268)
# Detected car: ID=4, BBox=(89, 298, 210, 334)
# [(438, 225, 521, 262, '2'), (392, 218, 504, 268, '3'), (89, 298, 210, 334, '4')]
#
# 0: 384x640 1 car, 29.7ms
# Speed: 4.0ms preprocess, 29.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(446, 223, 529, 260)
# Detected car: ID=3, BBox=(394, 215, 510, 267)
# Detected car: ID=4, BBox=(93, 296, 220, 335)
# [(446, 223, 529, 260, '2'), (394, 215, 510, 267, '3'), (93, 296, 220, 335, '4')]
#
# 0: 384x640 1 car, 29.1ms
# Speed: 3.7ms preprocess, 29.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(454, 221, 536, 258)
# Detected car: ID=3, BBox=(396, 213, 515, 266)
# Detected car: ID=4, BBox=(98, 294, 231, 335)
# [(454, 221, 536, 258, '2'), (396, 213, 515, 266, '3'), (98, 294, 231, 335, '4')]
#
# 0: 384x640 1 car, 29.9ms
# Speed: 3.7ms preprocess, 29.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(462, 220, 544, 256)
# Detected car: ID=3, BBox=(399, 210, 521, 265)
# Detected car: ID=4, BBox=(104, 292, 241, 335)
# [(462, 220, 544, 256, '2'), (399, 210, 521, 265, '3'), (104, 292, 241, 335, '4')]
#
# 0: 384x640 1 car, 29.7ms
# Speed: 3.7ms preprocess, 29.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(470, 218, 552, 255)
# Detected car: ID=3, BBox=(401, 208, 526, 264)
# Detected car: ID=4, BBox=(110, 291, 251, 334)
# [(470, 218, 552, 255, '2'), (401, 208, 526, 264, '3'), (110, 291, 251, 334, '4')]
#
# 0: 384x640 1 car, 29.3ms
# Speed: 3.6ms preprocess, 29.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(478, 216, 560, 253)
# Detected car: ID=3, BBox=(403, 205, 532, 263)
# Detected car: ID=4, BBox=(119, 289, 260, 333)
# [(478, 216, 560, 253, '2'), (403, 205, 532, 263, '3'), (119, 289, 260, 333, '4')]
#
# 0: 384x640 1 car, 29.8ms
# Speed: 3.7ms preprocess, 29.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(486, 214, 568, 251)
# Detected car: ID=3, BBox=(405, 203, 537, 262)
# Detected car: ID=4, BBox=(129, 287, 268, 331)
# [(486, 214, 568, 251, '2'), (405, 203, 537, 262, '3'), (129, 287, 268, 331, '4')]
#
# 0: 384x640 1 car, 29.0ms
# Speed: 3.6ms preprocess, 29.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(494, 213, 576, 249)
# Detected car: ID=3, BBox=(407, 200, 543, 261)
# Detected car: ID=4, BBox=(138, 284, 276, 329)
# [(494, 213, 576, 249, '2'), (407, 200, 543, 261, '3'), (138, 284, 276, 329, '4')]
#
# 0: 384x640 1 car, 29.2ms
# Speed: 3.4ms preprocess, 29.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(502, 211, 583, 247)
# Detected car: ID=3, BBox=(410, 198, 548, 260)
# Detected car: ID=4, BBox=(148, 282, 282, 326)
# [(502, 211, 583, 247, '2'), (410, 198, 548, 260, '3'), (148, 282, 282, 326, '4')]
#
# 0: 384x640 1 car, 30.0ms
# Speed: 3.8ms preprocess, 30.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(510, 209, 591, 245)
# Detected car: ID=3, BBox=(412, 195, 554, 259)
# Detected car: ID=4, BBox=(156, 280, 291, 325)
# [(510, 209, 591, 245, '2'), (412, 195, 554, 259, '3'), (156, 280, 291, 325, '4')]
#
# 0: 384x640 1 car, 29.7ms
# Speed: 4.0ms preprocess, 29.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(518, 207, 599, 244)
# Detected car: ID=3, BBox=(414, 193, 559, 257)
# Detected car: ID=4, BBox=(166, 278, 295, 322)
# [(518, 207, 599, 244, '2'), (414, 193, 559, 257, '3'), (166, 278, 295, 322, '4')]
#
# 0: 384x640 1 car, 28.8ms
# Speed: 3.6ms preprocess, 28.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(526, 206, 607, 242)
# Detected car: ID=3, BBox=(416, 190, 565, 256)
# Detected car: ID=4, BBox=(175, 277, 303, 321)
# [(526, 206, 607, 242, '2'), (416, 190, 565, 256, '3'), (175, 277, 303, 321, '4')]
#
# 0: 384x640 1 car, 30.1ms
# Speed: 3.8ms preprocess, 30.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(534, 204, 615, 240)
# Detected car: ID=3, BBox=(419, 188, 570, 255)
# Detected car: ID=4, BBox=(183, 275, 310, 319)
# [(534, 204, 615, 240, '2'), (419, 188, 570, 255, '3'), (183, 275, 310, 319, '4')]
#
# 0: 384x640 1 car, 29.4ms
# Speed: 3.5ms preprocess, 29.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(542, 202, 623, 238)
# Detected car: ID=3, BBox=(421, 185, 576, 254)
# Detected car: ID=4, BBox=(194, 273, 316, 316)
# [(542, 202, 623, 238, '2'), (421, 185, 576, 254, '3'), (194, 273, 316, 316, '4')]
#
# 0: 384x640 1 car, 29.8ms
# Speed: 3.4ms preprocess, 29.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(550, 200, 631, 236)
# Detected car: ID=3, BBox=(423, 183, 581, 253)
# Detected car: ID=4, BBox=(201, 271, 322, 314)
# [(550, 200, 631, 236, '2'), (423, 183, 581, 253, '3'), (201, 271, 322, 314, '4')]
#
# 0: 384x640 1 car, 29.1ms
# Speed: 3.7ms preprocess, 29.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(559, 199, 638, 234)
# Detected car: ID=3, BBox=(425, 180, 587, 252)
# Detected car: ID=4, BBox=(208, 269, 330, 312)
# [(559, 199, 638, 234, '2'), (425, 180, 587, 252, '3'), (208, 269, 330, 312, '4')]
#
# 0: 384x640 1 car, 29.9ms
# Speed: 3.5ms preprocess, 29.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(567, 197, 646, 232)
# Detected car: ID=3, BBox=(427, 178, 592, 251)
# Detected car: ID=4, BBox=(217, 267, 338, 311)
# [(567, 197, 646, 232, '2'), (427, 178, 592, 251, '3'), (217, 267, 338, 311, '4')]
#
# 0: 384x640 1 car, 30.0ms
# Speed: 4.1ms preprocess, 30.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(575, 195, 654, 231)
# Detected car: ID=3, BBox=(430, 175, 598, 250)
# Detected car: ID=4, BBox=(225, 265, 345, 309)
# [(575, 195, 654, 231, '2'), (430, 175, 598, 250, '3'), (225, 265, 345, 309, '4')]
#
# 0: 384x640 1 car, 29.2ms
# Speed: 3.6ms preprocess, 29.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=2, BBox=(583, 193, 662, 229)
# Detected car: ID=3, BBox=(432, 173, 603, 249)
# Detected car: ID=4, BBox=(234, 263, 351, 307)
# [(583, 193, 662, 229, '2'), (432, 173, 603, 249, '3'), (234, 263, 351, 307, '4')]
#
# 0: 384x640 1 car, 29.3ms
# Speed: 3.3ms preprocess, 29.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=3, BBox=(434, 170, 609, 248)
# Detected car: ID=4, BBox=(243, 261, 358, 305)
# [(434, 170, 609, 248, '3'), (243, 261, 358, 305, '4')]
#
# 0: 384x640 1 car, 29.3ms
# Speed: 3.6ms preprocess, 29.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=3, BBox=(436, 168, 614, 247)
# Detected car: ID=4, BBox=(251, 260, 365, 303)
# [(436, 168, 614, 247, '3'), (251, 260, 365, 303, '4')]
#
# 0: 384x640 1 car, 29.8ms
# Speed: 3.3ms preprocess, 29.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=3, BBox=(438, 165, 620, 246)
# Detected car: ID=4, BBox=(258, 258, 371, 301)
# [(438, 165, 620, 246, '3'), (258, 258, 371, 301, '4')]
#
# 0: 384x640 1 car, 29.9ms
# Speed: 3.4ms preprocess, 29.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=3, BBox=(441, 163, 625, 245)
# Detected car: ID=4, BBox=(267, 256, 380, 299)
# [(441, 163, 625, 245, '3'), (267, 256, 380, 299, '4')]
#
# 0: 384x640 1 car, 30.2ms
# Speed: 3.7ms preprocess, 30.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=3, BBox=(443, 160, 631, 244)
# Detected car: ID=4, BBox=(276, 254, 388, 297)
# [(443, 160, 631, 244, '3'), (276, 254, 388, 297, '4')]
#
# 0: 384x640 1 car, 30.0ms
# Speed: 3.9ms preprocess, 30.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(283, 252, 394, 295)
# [(283, 252, 394, 295, '4')]
#
# 0: 384x640 1 car, 29.3ms
# Speed: 3.6ms preprocess, 29.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(292, 250, 402, 293)
# [(292, 250, 402, 293, '4')]
#
# 0: 384x640 1 car, 29.4ms
# Speed: 3.7ms preprocess, 29.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(300, 249, 408, 291)
# [(300, 249, 408, 291, '4')]
#
# 0: 384x640 1 car, 30.2ms
# Speed: 3.6ms preprocess, 30.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(307, 247, 414, 289)
# [(307, 247, 414, 289, '4')]
#
# 0: 384x640 1 car, 29.7ms
# Speed: 3.6ms preprocess, 29.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(316, 245, 422, 288)
# [(316, 245, 422, 288, '4')]
#
# 0: 384x640 (no detections), 29.3ms
# Speed: 3.5ms preprocess, 29.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(323, 244, 430, 286)
# [(323, 244, 430, 286, '4')]
#
# 0: 384x640 1 car, 31.8ms
# Speed: 3.9ms preprocess, 31.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(331, 242, 437, 284)
# [(331, 242, 437, 284, '4')]
#
# 0: 384x640 1 car, 29.6ms
# Speed: 3.7ms preprocess, 29.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(340, 240, 444, 282)
# [(340, 240, 444, 282, '4')]
#
# 0: 384x640 1 car, 29.5ms
# Speed: 3.4ms preprocess, 29.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(348, 239, 452, 280)
# [(348, 239, 452, 280, '4')]
#
# 0: 384x640 1 car, 29.6ms
# Speed: 3.3ms preprocess, 29.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(355, 237, 459, 278)
# [(355, 237, 459, 278, '4')]
#
# 0: 384x640 1 car, 30.0ms
# Speed: 3.5ms preprocess, 30.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(359, 234, 466, 277)
# [(359, 234, 466, 277, '4')]
#
# 0: 384x640 1 bus, 30.2ms
# Speed: 3.5ms preprocess, 30.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(366, 232, 473, 275)
# [(366, 232, 473, 275, '4')]
#
# 0: 384x640 1 car, 30.0ms
# Speed: 3.9ms preprocess, 30.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(374, 231, 480, 273)
# [(374, 231, 480, 273, '4')]
#
# 0: 384x640 (no detections), 29.8ms
# Speed: 3.5ms preprocess, 29.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(381, 229, 488, 271)
# [(381, 229, 488, 271, '4')]
#
# 0: 384x640 (no detections), 31.3ms
# Speed: 3.6ms preprocess, 31.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(388, 227, 495, 269)
# [(388, 227, 495, 269, '4')]
#
# 0: 384x640 1 car, 31.6ms
# Speed: 3.6ms preprocess, 31.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(395, 225, 503, 267)
# [(395, 225, 503, 267, '4')]
#
# 0: 384x640 (no detections), 30.0ms
# Speed: 3.6ms preprocess, 30.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(403, 223, 510, 266)
# [(403, 223, 510, 266, '4')]
#
# 0: 384x640 1 car, 32.3ms
# Speed: 2.7ms preprocess, 32.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(410, 221, 517, 264)
# [(410, 221, 517, 264, '4')]
#
# 0: 384x640 (no detections), 30.3ms
# Speed: 2.7ms preprocess, 30.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(417, 219, 525, 262)
# [(417, 219, 525, 262, '4')]
#
# 0: 384x640 (no detections), 32.1ms
# Speed: 3.2ms preprocess, 32.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(425, 218, 532, 260)
# [(425, 218, 532, 260, '4')]
#
# 0: 384x640 (no detections), 30.8ms
# Speed: 3.3ms preprocess, 30.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(432, 216, 539, 258)
# [(432, 216, 539, 258, '4')]
#
# 0: 384x640 1 car, 33.3ms
# Speed: 1.9ms preprocess, 33.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(439, 214, 547, 257)
# [(439, 214, 547, 257, '4')]
#
# 0: 384x640 1 car, 30.8ms
# Speed: 3.5ms preprocess, 30.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(447, 212, 554, 255)
# Detected car: ID=8, BBox=(78, 301, 186, 335)
# [(447, 212, 554, 255, '4'), (78, 301, 186, 335, '8')]
#
# 0: 384x640 1 car, 29.3ms
# Speed: 3.8ms preprocess, 29.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(454, 210, 562, 253)
# Detected car: ID=8, BBox=(83, 299, 196, 334)
# [(454, 210, 562, 253, '4'), (83, 299, 196, 334, '8')]
#
# 0: 384x640 1 car, 29.9ms
# Speed: 4.0ms preprocess, 29.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(461, 208, 569, 251)
# Detected car: ID=8, BBox=(89, 298, 206, 335)
# [(461, 208, 569, 251, '4'), (89, 298, 206, 335, '8')]
#
# 0: 384x640 1 car, 1 truck, 30.0ms
# Speed: 3.2ms preprocess, 30.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(468, 206, 576, 249)
# Detected car: ID=8, BBox=(94, 295, 217, 335)
# [(468, 206, 576, 249, '4'), (94, 295, 217, 335, '8')]
#
# 0: 384x640 1 car, 1 truck, 29.4ms
# Speed: 3.5ms preprocess, 29.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(476, 205, 584, 247)
# Detected car: ID=8, BBox=(100, 293, 227, 334)
# [(476, 205, 584, 247, '4'), (100, 293, 227, 334, '8')]
# Detected truck: ID=1, BBox=(1, 134, 47, 204)
#
# 0: 384x640 1 car, 1 truck, 28.6ms
# Speed: 3.6ms preprocess, 28.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(483, 203, 591, 246)
# Detected car: ID=8, BBox=(108, 291, 234, 333)
# [(483, 203, 591, 246, '4'), (108, 291, 234, 333, '8')]
# Detected truck: ID=1, BBox=(3, 133, 49, 203)
#
# 0: 384x640 1 car, 1 truck, 29.4ms
# Speed: 4.1ms preprocess, 29.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(490, 201, 599, 244)
# Detected car: ID=8, BBox=(117, 290, 242, 331)
# [(490, 201, 599, 244, '4'), (117, 290, 242, 331, '8')]
# Detected truck: ID=1, BBox=(4, 130, 52, 202)
#
# 0: 384x640 1 car, 1 truck, 29.4ms
# Speed: 3.6ms preprocess, 29.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(498, 199, 606, 242)
# Detected car: ID=8, BBox=(125, 288, 251, 330)
# [(498, 199, 606, 242, '4'), (125, 288, 251, 330, '8')]
# Detected truck: ID=1, BBox=(5, 129, 54, 202)
#
# 0: 384x640 1 car, 1 truck, 28.7ms
# Speed: 3.7ms preprocess, 28.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(505, 197, 613, 240)
# Detected car: ID=8, BBox=(134, 286, 258, 328)
# [(505, 197, 613, 240, '4'), (134, 286, 258, 328, '8')]
# Detected truck: ID=1, BBox=(7, 129, 56, 202)
#
# 0: 384x640 1 car, 1 truck, 29.5ms
# Speed: 4.0ms preprocess, 29.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(512, 195, 621, 238)
# Detected car: ID=8, BBox=(142, 284, 265, 326)
# [(512, 195, 621, 238, '4'), (142, 284, 265, 326, '8')]
# Detected truck: ID=1, BBox=(8, 128, 59, 203)
#
# 0: 384x640 1 car, 1 truck, 29.6ms
# Speed: 3.6ms preprocess, 29.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(519, 193, 628, 237)
# Detected car: ID=8, BBox=(151, 282, 272, 324)
# [(519, 193, 628, 237, '4'), (151, 282, 272, 324, '8')]
# Detected truck: ID=1, BBox=(9, 128, 62, 203)
#
# 0: 384x640 1 car, 1 truck, 28.6ms
# Speed: 3.7ms preprocess, 28.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(527, 192, 636, 235)
# Detected car: ID=8, BBox=(161, 280, 278, 322)
# [(527, 192, 636, 235, '4'), (161, 280, 278, 322, '8')]
# Detected truck: ID=1, BBox=(9, 127, 65, 204)
#
# 0: 384x640 1 car, 1 truck, 29.5ms
# Speed: 3.3ms preprocess, 29.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(534, 190, 643, 233)
# Detected car: ID=8, BBox=(170, 279, 285, 320)
# [(534, 190, 643, 233, '4'), (170, 279, 285, 320, '8')]
# Detected truck: ID=1, BBox=(10, 126, 68, 204)
#
# 0: 384x640 1 car, 28.8ms
# Speed: 3.7ms preprocess, 28.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(541, 188, 650, 231)
# Detected car: ID=8, BBox=(179, 277, 292, 318)
# [(541, 188, 650, 231, '4'), (179, 277, 292, 318, '8')]
# Detected truck: ID=1, BBox=(11, 125, 70, 205)
#
# 0: 384x640 1 car, 1 truck, 29.1ms
# Speed: 3.7ms preprocess, 29.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(549, 186, 658, 229)
# Detected car: ID=8, BBox=(186, 275, 298, 316)
# [(549, 186, 658, 229, '4'), (186, 275, 298, 316, '8')]
# Detected truck: ID=1, BBox=(11, 124, 73, 205)
#
# 0: 384x640 1 car, 1 truck, 29.5ms
# Speed: 3.8ms preprocess, 29.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(556, 184, 665, 227)
# Detected car: ID=8, BBox=(195, 273, 305, 314)
# [(556, 184, 665, 227, '4'), (195, 273, 305, 314, '8')]
# Detected truck: ID=1, BBox=(10, 124, 77, 208)
#
# 0: 384x640 1 car, 1 truck, 28.6ms
# Speed: 3.8ms preprocess, 28.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(563, 182, 672, 226)
# Detected car: ID=8, BBox=(202, 271, 311, 312)
# [(563, 182, 672, 226, '4'), (202, 271, 311, 312, '8')]
# Detected truck: ID=1, BBox=(11, 123, 81, 208)
#
# 0: 384x640 1 car, 1 truck, 29.3ms
# Speed: 4.0ms preprocess, 29.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(571, 180, 680, 224)
# Detected car: ID=8, BBox=(209, 269, 319, 310)
# [(571, 180, 680, 224, '4'), (209, 269, 319, 310, '8')]
# Detected truck: ID=1, BBox=(11, 123, 84, 209)
#
# 0: 384x640 1 car, 1 truck, 35.7ms
# Speed: 3.4ms preprocess, 35.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=4, BBox=(578, 179, 687, 222)
# Detected car: ID=8, BBox=(218, 267, 326, 308)
# [(578, 179, 687, 222, '4'), (218, 267, 326, 308, '8')]
# Detected truck: ID=1, BBox=(11, 122, 87, 209)
#
# 0: 384x640 1 car, 35.7ms
# Speed: 3.7ms preprocess, 35.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(226, 265, 332, 306)
# [(226, 265, 332, 306, '8')]
# Detected truck: ID=1, BBox=(12, 121, 89, 209)
#
# 0: 384x640 1 car, 35.8ms
# Speed: 3.5ms preprocess, 35.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(235, 263, 339, 304)
# [(235, 263, 339, 304, '8')]
# Detected truck: ID=1, BBox=(13, 120, 91, 210)
#
# 0: 384x640 1 car, 1 train, 35.7ms
# Speed: 3.4ms preprocess, 35.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(244, 262, 344, 302)
# [(244, 262, 344, 302, '8')]
# Detected truck: ID=1, BBox=(14, 119, 94, 210)
#
# 0: 384x640 1 car, 35.2ms
# Speed: 3.5ms preprocess, 35.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(251, 260, 352, 300)
# [(251, 260, 352, 300, '8')]
# Detected truck: ID=1, BBox=(16, 119, 96, 210)
#
# 0: 384x640 1 car, 35.8ms
# Speed: 3.7ms preprocess, 35.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(259, 259, 359, 299)
# [(259, 259, 359, 299, '8')]
# Detected truck: ID=1, BBox=(17, 118, 98, 211)
#
# 0: 384x640 1 car, 36.4ms
# Speed: 3.8ms preprocess, 36.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(266, 257, 366, 297)
# [(266, 257, 366, 297, '8')]
# Detected truck: ID=1, BBox=(18, 117, 100, 211)
#
# 0: 384x640 1 car, 35.6ms
# Speed: 3.8ms preprocess, 35.6ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(274, 255, 375, 295)
# [(274, 255, 375, 295, '8')]
# Detected truck: ID=1, BBox=(19, 116, 102, 212)
#
# 0: 384x640 1 car, 39.8ms
# Speed: 4.2ms preprocess, 39.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(282, 253, 382, 294)
# [(282, 253, 382, 294, '8')]
# Detected truck: ID=1, BBox=(20, 115, 105, 212)
#
# 0: 384x640 1 car, 35.5ms
# Speed: 3.6ms preprocess, 35.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(291, 252, 388, 292)
# [(291, 252, 388, 292, '8')]
# Detected truck: ID=1, BBox=(21, 115, 107, 212)
#
# 0: 384x640 1 car, 37.3ms
# Speed: 3.7ms preprocess, 37.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(299, 250, 395, 289)
# [(299, 250, 395, 289, '8')]
# Detected truck: ID=1, BBox=(23, 114, 109, 213)
#
# 0: 384x640 1 car, 35.8ms
# Speed: 3.9ms preprocess, 35.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(307, 249, 402, 287)
# [(307, 249, 402, 287, '8')]
# Detected truck: ID=1, BBox=(24, 113, 111, 213)
#
# 0: 384x640 1 car, 35.7ms
# Speed: 3.8ms preprocess, 35.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(312, 247, 410, 286)
# [(312, 247, 410, 286, '8')]
# Detected truck: ID=1, BBox=(25, 112, 113, 214)
#
# 0: 384x640 1 car, 1 truck, 37.1ms
# Speed: 3.8ms preprocess, 37.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(320, 245, 416, 284)
# [(320, 245, 416, 284, '8')]
# Detected truck: ID=1, BBox=(26, 112, 116, 214)
#
# 0: 384x640 1 truck, 37.2ms
# Speed: 3.9ms preprocess, 37.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(328, 244, 423, 283)
# [(328, 244, 423, 283, '8')]
# Detected truck: ID=1, BBox=(27, 111, 118, 214)
# Detected truck: ID=2, BBox=(1, 115, 138, 201)
#
# 0: 384x640 2 cars, 1 truck, 36.8ms
# Speed: 3.8ms preprocess, 36.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(335, 242, 430, 281)
# [(335, 242, 430, 281, '8')]
# Detected truck: ID=1, BBox=(28, 110, 120, 215)
# Detected truck: ID=2, BBox=(3, 114, 141, 200)
#
# 0: 384x640 2 cars, 1 truck, 36.5ms
# Speed: 3.7ms preprocess, 36.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(343, 240, 437, 279)
# Detected car: ID=9, BBox=(2, 224, 35, 268)
# [(343, 240, 437, 279, '8'), (2, 224, 35, 268, '9')]
# Detected truck: ID=1, BBox=(29, 109, 122, 215)
# Detected truck: ID=2, BBox=(4, 113, 142, 200)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 38.9ms
# Speed: 2.4ms preprocess, 38.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(350, 239, 445, 277)
# Detected car: ID=9, BBox=(4, 222, 38, 267)
# [(350, 239, 445, 277, '8'), (4, 222, 38, 267, '9')]
# Detected truck: ID=1, BBox=(31, 108, 124, 216)
# Detected truck: ID=2, BBox=(4, 112, 144, 199)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 37.4ms
# Speed: 2.4ms preprocess, 37.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(357, 237, 451, 276)
# Detected car: ID=9, BBox=(6, 221, 39, 266)
# [(357, 237, 451, 276, '8'), (6, 221, 39, 266, '9')]
# Detected bus: ID=3, BBox=(2, 59, 40, 131)
# Detected truck: ID=1, BBox=(32, 108, 127, 216)
# Detected truck: ID=2, BBox=(5, 111, 145, 199)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 37.1ms
# Speed: 3.6ms preprocess, 37.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(364, 236, 459, 274)
# Detected car: ID=9, BBox=(7, 220, 40, 265)
# [(364, 236, 459, 274, '8'), (7, 220, 40, 265, '9')]
# Detected bus: ID=3, BBox=(5, 58, 44, 130)
# Detected truck: ID=1, BBox=(33, 107, 129, 216)
# Detected truck: ID=2, BBox=(6, 111, 145, 198)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 35.8ms
# Speed: 3.8ms preprocess, 35.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(372, 234, 467, 273)
# Detected car: ID=9, BBox=(8, 219, 42, 265)
# [(372, 234, 467, 273, '8'), (8, 219, 42, 265, '9')]
# Detected bus: ID=3, BBox=(7, 57, 48, 129)
# Detected truck: ID=1, BBox=(34, 106, 131, 217)
# Detected truck: ID=2, BBox=(6, 111, 147, 197)
#
# 0: 384x640 1 car, 1 bus, 36.2ms
# Speed: 3.4ms preprocess, 36.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(379, 232, 474, 271)
# Detected car: ID=9, BBox=(10, 219, 43, 264)
# [(379, 232, 474, 271, '8'), (10, 219, 43, 264, '9')]
# Detected bus: ID=3, BBox=(10, 56, 52, 129)
# Detected truck: ID=1, BBox=(35, 105, 133, 217)
# Detected truck: ID=2, BBox=(7, 110, 148, 197)
#
# 0: 384x640 1 car, 1 bus, 35.8ms
# Speed: 3.6ms preprocess, 35.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(386, 230, 479, 269)
# Detected car: ID=9, BBox=(11, 218, 45, 263)
# [(386, 230, 479, 269, '8'), (11, 218, 45, 263, '9')]
# Detected bus: ID=3, BBox=(13, 55, 56, 129)
# Detected truck: ID=1, BBox=(36, 105, 135, 218)
# Detected truck: ID=2, BBox=(8, 110, 149, 196)
#
# 0: 384x640 1 car, 35.8ms
# Speed: 3.5ms preprocess, 35.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(393, 229, 484, 267)
# Detected car: ID=9, BBox=(12, 217, 46, 263)
# [(393, 229, 484, 267, '8'), (12, 217, 46, 263, '9')]
# Detected bus: ID=3, BBox=(15, 54, 59, 129)
# Detected truck: ID=1, BBox=(38, 104, 137, 218)
# Detected truck: ID=2, BBox=(9, 109, 150, 196)
#
# 0: 384x640 1 car, 35.7ms
# Speed: 3.3ms preprocess, 35.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(400, 228, 493, 265)
# Detected car: ID=9, BBox=(14, 216, 48, 262)
# [(400, 228, 493, 265, '8'), (14, 216, 48, 262, '9')]
# Detected bus: ID=3, BBox=(18, 53, 62, 129)
# Detected truck: ID=1, BBox=(39, 103, 140, 219)
# Detected truck: ID=2, BBox=(10, 108, 151, 195)
#
# 0: 384x640 1 car, 1 bus, 35.5ms
# Speed: 3.1ms preprocess, 35.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(407, 226, 502, 264)
# Detected car: ID=9, BBox=(15, 215, 49, 261)
# [(407, 226, 502, 264, '8'), (15, 215, 49, 261, '9')]
# Detected bus: ID=3, BBox=(21, 52, 65, 129)
# Detected truck: ID=1, BBox=(40, 102, 142, 219)
# Detected truck: ID=2, BBox=(11, 108, 152, 195)
#
# 0: 384x640 1 bus, 30.8ms
# Speed: 3.6ms preprocess, 30.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(415, 224, 509, 263)
# Detected car: ID=9, BBox=(16, 214, 50, 260)
# [(415, 224, 509, 263, '8'), (16, 214, 50, 260, '9')]
# Detected bus: ID=3, BBox=(23, 51, 68, 129)
# Detected bus: ID=4, BBox=(2, 50, 93, 154)
# Detected truck: ID=1, BBox=(41, 101, 144, 219)
# Detected truck: ID=2, BBox=(12, 107, 153, 194)
#
# 0: 384x640 1 bus, 30.9ms
# Speed: 3.7ms preprocess, 30.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(422, 222, 516, 261)
# Detected car: ID=9, BBox=(18, 214, 52, 260)
# [(422, 222, 516, 261, '8'), (18, 214, 52, 260, '9')]
# Detected bus: ID=3, BBox=(26, 50, 71, 129)
# Detected bus: ID=4, BBox=(4, 49, 96, 154)
# Detected truck: ID=1, BBox=(42, 101, 146, 220)
# Detected truck: ID=2, BBox=(13, 107, 154, 194)
#
# 0: 384x640 1 bus, 30.7ms
# Speed: 3.6ms preprocess, 30.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(429, 221, 524, 259)
# Detected car: ID=9, BBox=(19, 213, 53, 259)
# [(429, 221, 524, 259, '8'), (19, 213, 53, 259, '9')]
# Detected bus: ID=3, BBox=(28, 50, 74, 128)
# Detected bus: ID=4, BBox=(7, 47, 101, 154)
# Detected truck: ID=1, BBox=(43, 100, 148, 220)
# Detected truck: ID=2, BBox=(14, 106, 156, 193)
#
# 0: 384x640 (no detections), 30.9ms
# Speed: 2.1ms preprocess, 30.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(436, 219, 531, 258)
# Detected car: ID=9, BBox=(20, 212, 55, 258)
# [(436, 219, 531, 258, '8'), (20, 212, 55, 258, '9')]
# Detected bus: ID=3, BBox=(31, 49, 77, 128)
# Detected bus: ID=4, BBox=(9, 46, 104, 154)
# Detected truck: ID=1, BBox=(45, 99, 151, 221)
# Detected truck: ID=2, BBox=(15, 106, 157, 193)
#
# 0: 384x640 (no detections), 33.9ms
# Speed: 1.9ms preprocess, 33.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(444, 217, 538, 256)
# Detected car: ID=9, BBox=(21, 211, 56, 258)
# [(444, 217, 538, 256, '8'), (21, 211, 56, 258, '9')]
# Detected bus: ID=3, BBox=(33, 48, 80, 128)
# Detected bus: ID=4, BBox=(11, 45, 106, 154)
# Detected truck: ID=1, BBox=(46, 98, 153, 221)
# Detected truck: ID=2, BBox=(16, 105, 158, 192)
#
# 0: 384x640 (no detections), 32.7ms
# Speed: 1.9ms preprocess, 32.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(451, 216, 545, 254)
# Detected car: ID=9, BBox=(23, 210, 58, 257)
# [(451, 216, 545, 254, '8'), (23, 210, 58, 257, '9')]
# Detected bus: ID=3, BBox=(36, 47, 83, 128)
# Detected bus: ID=4, BBox=(13, 44, 109, 154)
# Detected truck: ID=2, BBox=(17, 105, 159, 192)
#
# 0: 384x640 1 bus, 33.5ms
# Speed: 2.1ms preprocess, 33.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(458, 214, 553, 253)
# Detected car: ID=9, BBox=(24, 209, 59, 256)
# [(458, 214, 553, 253, '8'), (24, 209, 59, 256, '9')]
# Detected bus: ID=3, BBox=(39, 46, 86, 128)
# Detected bus: ID=4, BBox=(14, 43, 112, 154)
# Detected truck: ID=2, BBox=(18, 104, 160, 191)
#
# 0: 384x640 1 bus, 30.6ms
# Speed: 3.4ms preprocess, 30.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=8, BBox=(465, 212, 560, 251)
# ...
# Detected car: ID=10, BBox=(181, 181, 270, 222)
# Detected car: ID=11, BBox=(572, 192, 664, 229)
# [(181, 181, 270, 222, '10'), (572, 192, 664, 229, '11')]
# Detected bus: ID=10, BBox=(26, 83, 131, 176)
#
# 0: 384x640 1 car, 1 bus, 47.2ms
# Speed: 3.2ms preprocess, 47.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(184, 181, 272, 222)
# Detected car: ID=11, BBox=(580, 190, 672, 227)
# [(184, 181, 272, 222, '10'), (580, 190, 672, 227, '11')]
# Detected bus: ID=10, BBox=(28, 82, 139, 174)
#
# 0: 384x640 1 car, 1 bus, 48.7ms
# Speed: 2.8ms preprocess, 48.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(186, 180, 274, 221)
# Detected car: ID=11, BBox=(589, 188, 680, 225)
# [(186, 180, 274, 221, '10'), (589, 188, 680, 225, '11')]
# Detected bus: ID=10, BBox=(28, 80, 145, 173)
#
# 0: 384x640 1 car, 1 bus, 43.3ms
# Speed: 3.3ms preprocess, 43.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(187, 180, 275, 221)
# Detected car: ID=11, BBox=(598, 187, 688, 223)
# [(187, 180, 275, 221, '10'), (598, 187, 688, 223, '11')]
# Detected bus: ID=10, BBox=(29, 79, 151, 171)
#
# 0: 384x640 1 car, 1 bus, 45.1ms
# Speed: 3.7ms preprocess, 45.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(186, 179, 279, 222)
# Detected car: ID=11, BBox=(606, 185, 697, 221)
# [(186, 179, 279, 222, '10'), (606, 185, 697, 221, '11')]
# Detected bus: ID=10, BBox=(29, 78, 158, 170)
#
# 0: 384x640 1 car, 1 bus, 50.6ms
# Speed: 3.8ms preprocess, 50.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(188, 178, 280, 222)
# [(188, 178, 280, 222, '10')]
# Detected bus: ID=10, BBox=(31, 76, 165, 168)
#
# 0: 384x640 1 car, 1 bus, 45.8ms
# Speed: 3.4ms preprocess, 45.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(189, 178, 281, 221)
# [(189, 178, 281, 221, '10')]
# Detected bus: ID=10, BBox=(34, 74, 172, 166)
#
# 0: 384x640 1 car, 1 bus, 41.8ms
# Speed: 3.7ms preprocess, 41.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(191, 178, 281, 221)
# [(191, 178, 281, 221, '10')]
# Detected bus: ID=10, BBox=(42, 74, 182, 163)
#
# 0: 384x640 1 car, 1 bus, 41.9ms
# Speed: 3.6ms preprocess, 41.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(193, 178, 282, 220)
# [(193, 178, 282, 220, '10')]
# Detected bus: ID=10, BBox=(45, 70, 193, 162)
#
# 0: 384x640 1 car, 1 bus, 41.9ms
# Speed: 3.5ms preprocess, 41.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(195, 178, 283, 220)
# [(195, 178, 283, 220, '10')]
# Detected bus: ID=10, BBox=(48, 68, 199, 160)
#
# 0: 384x640 1 car, 39.0ms
# Speed: 3.7ms preprocess, 39.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(196, 177, 282, 219)
# [(196, 177, 282, 219, '10')]
# Detected bus: ID=10, BBox=(52, 67, 204, 159)
#
# 0: 384x640 1 car, 37.9ms
# Speed: 3.5ms preprocess, 37.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(196, 177, 283, 218)
# [(196, 177, 283, 218, '10')]
# Detected bus: ID=10, BBox=(57, 65, 209, 158)
#
# 0: 384x640 1 car, 37.8ms
# Speed: 3.8ms preprocess, 37.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(197, 176, 283, 218)
# [(197, 176, 283, 218, '10')]
# Detected bus: ID=10, BBox=(61, 64, 214, 157)
#
# 0: 384x640 (no detections), 37.7ms
# Speed: 3.7ms preprocess, 37.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(199, 176, 284, 218)
# [(199, 176, 284, 218, '10')]
# Detected bus: ID=10, BBox=(65, 62, 219, 156)
#
# 0: 384x640 (no detections), 37.8ms
# Speed: 3.8ms preprocess, 37.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(200, 176, 286, 217)
# [(200, 176, 286, 217, '10')]
# Detected bus: ID=10, BBox=(69, 60, 223, 154)
#
# 0: 384x640 (no detections), 37.7ms
# Speed: 1.8ms preprocess, 37.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(202, 175, 287, 217)
# [(202, 175, 287, 217, '10')]
# Detected bus: ID=10, BBox=(74, 59, 228, 153)
#
# 0: 384x640 1 car, 37.7ms
# Speed: 1.9ms preprocess, 37.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(203, 175, 289, 217)
# [(203, 175, 289, 217, '10')]
# Detected bus: ID=10, BBox=(78, 57, 233, 152)
#
# 0: 384x640 1 car, 34.0ms
# Speed: 3.8ms preprocess, 34.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(204, 174, 290, 216)
# Detected car: ID=12, BBox=(119, 288, 225, 333)
# [(204, 174, 290, 216, '10'), (119, 288, 225, 333, '12')]
# Detected bus: ID=10, BBox=(82, 55, 238, 151)
#
# 0: 384x640 1 car, 30.0ms
# Speed: 3.7ms preprocess, 30.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(206, 174, 291, 216)
# Detected car: ID=12, BBox=(126, 286, 234, 332)
# [(206, 174, 291, 216, '10'), (126, 286, 234, 332, '12')]
# Detected bus: ID=10, BBox=(87, 54, 243, 149)
#
# 0: 384x640 1 car, 30.0ms
# Speed: 3.5ms preprocess, 30.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(207, 174, 293, 215)
# Detected car: ID=12, BBox=(135, 284, 244, 330)
# [(207, 174, 293, 215, '10'), (135, 284, 244, 330, '12')]
# Detected bus: ID=10, BBox=(91, 52, 248, 148)
#
# 0: 384x640 1 car, 31.8ms
# Speed: 1.7ms preprocess, 31.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(208, 173, 294, 215)
# Detected car: ID=12, BBox=(146, 282, 251, 327)
# [(208, 173, 294, 215, '10'), (146, 282, 251, 327, '12')]
# Detected bus: ID=10, BBox=(95, 50, 253, 147)
#
# 0: 384x640 1 car, 31.6ms
# Speed: 1.8ms preprocess, 31.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(210, 173, 295, 215)
# Detected car: ID=12, BBox=(155, 280, 261, 325)
# [(210, 173, 295, 215, '10'), (155, 280, 261, 325, '12')]
# Detected bus: ID=10, BBox=(99, 49, 258, 146)
#
# 0: 384x640 1 car, 31.7ms
# Speed: 2.5ms preprocess, 31.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(211, 172, 297, 214)
# Detected car: ID=12, BBox=(163, 278, 269, 323)
# [(211, 172, 297, 214, '10'), (163, 278, 269, 323, '12')]
# Detected bus: ID=10, BBox=(104, 47, 263, 144)
#
# 0: 384x640 1 car, 30.4ms
# Speed: 2.8ms preprocess, 30.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(212, 172, 298, 214)
# Detected car: ID=12, BBox=(172, 276, 277, 321)
# [(212, 172, 298, 214, '10'), (172, 276, 277, 321, '12')]
# Detected bus: ID=10, BBox=(108, 46, 268, 143)
#
# 0: 384x640 1 car, 31.5ms
# Speed: 2.5ms preprocess, 31.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(214, 171, 299, 213)
# Detected car: ID=12, BBox=(180, 274, 286, 319)
# [(214, 171, 299, 213, '10'), (180, 274, 286, 319, '12')]
# Detected bus: ID=10, BBox=(112, 44, 273, 142)
#
# 0: 384x640 1 car, 29.1ms
# Speed: 3.8ms preprocess, 29.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(215, 171, 301, 213)
# Detected car: ID=12, BBox=(189, 272, 294, 317)
# [(215, 171, 301, 213, '10'), (189, 272, 294, 317, '12')]
# Detected bus: ID=10, BBox=(116, 42, 277, 141)
#
# 0: 384x640 1 car, 29.8ms
# Speed: 4.3ms preprocess, 29.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(216, 171, 302, 213)
# Detected car: ID=12, BBox=(198, 270, 304, 315)
# [(216, 171, 302, 213, '10'), (198, 270, 304, 315, '12')]
# Detected bus: ID=10, BBox=(121, 41, 282, 139)
#
# 0: 384x640 1 car, 30.0ms
# Speed: 3.6ms preprocess, 30.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(218, 170, 303, 212)
# Detected car: ID=12, BBox=(207, 268, 311, 312)
# [(218, 170, 303, 212, '10'), (207, 268, 311, 312, '12')]
# Detected bus: ID=10, BBox=(125, 39, 287, 138)
#
# 0: 384x640 2 cars, 30.1ms
# Speed: 3.6ms preprocess, 30.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(221, 172, 303, 213)
# Detected car: ID=12, BBox=(216, 266, 320, 310)
# [(221, 172, 303, 213, '10'), (216, 266, 320, 310, '12')]
# Detected bus: ID=10, BBox=(129, 37, 292, 137)
#
# 0: 384x640 2 cars, 29.3ms
# Speed: 3.7ms preprocess, 29.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(223, 172, 303, 213)
# Detected car: ID=12, BBox=(225, 264, 328, 308)
# [(223, 172, 303, 213, '10'), (225, 264, 328, 308, '12')]
# Detected bus: ID=10, BBox=(134, 36, 297, 136)
#
# 0: 384x640 2 cars, 29.5ms
# Speed: 3.4ms preprocess, 29.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(224, 172, 305, 213)
# Detected car: ID=12, BBox=(233, 262, 336, 305)
# [(224, 172, 305, 213, '10'), (233, 262, 336, 305, '12')]
# Detected bus: ID=10, BBox=(138, 34, 302, 134)
#
# 0: 384x640 2 cars, 29.8ms
# Speed: 2.5ms preprocess, 29.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(225, 171, 305, 213)
# Detected car: ID=12, BBox=(242, 260, 344, 303)
# [(225, 171, 305, 213, '10'), (242, 260, 344, 303, '12')]
# Detected bus: ID=10, BBox=(142, 33, 307, 133)
#
# 0: 384x640 2 cars, 31.0ms
# Speed: 1.9ms preprocess, 31.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(226, 171, 305, 213)
# Detected car: ID=12, BBox=(250, 257, 353, 301)
# [(226, 171, 305, 213, '10'), (250, 257, 353, 301, '12')]
# Detected bus: ID=10, BBox=(146, 31, 312, 132)
#
# 0: 384x640 1 car, 30.9ms
# Speed: 2.0ms preprocess, 30.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(227, 171, 307, 212)
# Detected car: ID=12, BBox=(258, 255, 361, 299)
# [(227, 171, 307, 212, '10'), (258, 255, 361, 299, '12')]
# Detected bus: ID=10, BBox=(151, 29, 317, 131)
#
# 0: 384x640 1 car, 29.9ms
# Speed: 3.4ms preprocess, 29.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(229, 171, 308, 212)
# Detected car: ID=12, BBox=(267, 253, 370, 297)
# [(229, 171, 308, 212, '10'), (267, 253, 370, 297, '12')]
# Detected bus: ID=10, BBox=(155, 28, 322, 129)
#
# 0: 384x640 1 car, 29.2ms
# Speed: 3.7ms preprocess, 29.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(230, 171, 309, 212)
# Detected car: ID=12, BBox=(277, 252, 378, 295)
# [(230, 171, 309, 212, '10'), (277, 252, 378, 295, '12')]
# Detected bus: ID=10, BBox=(159, 26, 327, 128)
#
# 0: 384x640 1 car, 29.9ms
# Speed: 3.9ms preprocess, 29.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(231, 170, 310, 212)
# Detected car: ID=12, BBox=(286, 250, 386, 293)
# [(231, 170, 310, 212, '10'), (286, 250, 386, 293, '12')]
# Detected bus: ID=10, BBox=(163, 24, 331, 127)
#
# 0: 384x640 (no detections), 30.1ms
# Speed: 3.3ms preprocess, 30.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(232, 170, 311, 211)
# Detected car: ID=12, BBox=(294, 249, 394, 291)
# [(232, 170, 311, 211, '10'), (294, 249, 394, 291, '12')]
# Detected bus: ID=10, BBox=(168, 23, 336, 126)
#
# 0: 384x640 1 car, 30.6ms
# Speed: 3.7ms preprocess, 30.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(233, 170, 312, 211)
# Detected car: ID=12, BBox=(302, 247, 402, 289)
# [(233, 170, 312, 211, '10'), (302, 247, 402, 289, '12')]
# Detected bus: ID=10, BBox=(172, 21, 341, 124)
#
# 0: 384x640 1 car, 29.2ms
# Speed: 3.5ms preprocess, 29.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(235, 170, 314, 211)
# Detected car: ID=12, BBox=(311, 246, 409, 287)
# [(235, 170, 314, 211, '10'), (311, 246, 409, 287, '12')]
# Detected bus: ID=10, BBox=(176, 20, 346, 123)
#
# 0: 384x640 1 car, 30.1ms
# Speed: 3.4ms preprocess, 30.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(235, 169, 313, 210)
# Detected car: ID=12, BBox=(320, 244, 417, 285)
# [(235, 169, 313, 210, '10'), (320, 244, 417, 285, '12')]
#
# 0: 384x640 2 cars, 29.8ms
# Speed: 3.0ms preprocess, 29.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(235, 169, 313, 210)
# Detected car: ID=12, BBox=(328, 242, 426, 283)
# [(235, 169, 313, 210, '10'), (328, 242, 426, 283, '12')]
#
# 0: 384x640 1 car, 29.7ms
# Speed: 2.7ms preprocess, 29.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(236, 169, 313, 210)
# Detected car: ID=12, BBox=(336, 240, 434, 281)
# [(236, 169, 313, 210, '10'), (336, 240, 434, 281, '12')]
#
# 0: 384x640 1 car, 28.7ms
# Speed: 3.3ms preprocess, 28.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(237, 169, 314, 209)
# Detected car: ID=12, BBox=(345, 238, 442, 279)
# [(237, 169, 314, 209, '10'), (345, 238, 442, 279, '12')]
#
# 0: 384x640 2 cars, 29.8ms
# Speed: 3.1ms preprocess, 29.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(239, 169, 313, 209)
# Detected car: ID=12, BBox=(353, 237, 448, 277)
# [(239, 169, 313, 209, '10'), (353, 237, 448, 277, '12')]
#
# 0: 384x640 2 cars, 28.8ms
# Speed: 2.9ms preprocess, 28.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(240, 169, 314, 208)
# Detected car: ID=12, BBox=(359, 234, 457, 275)
# [(240, 169, 314, 208, '10'), (359, 234, 457, 275, '12')]
#
# 0: 384x640 2 cars, 29.2ms
# Speed: 2.6ms preprocess, 29.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(241, 169, 315, 208)
# Detected car: ID=12, BBox=(367, 232, 464, 273)
# [(241, 169, 315, 208, '10'), (367, 232, 464, 273, '12')]
#
# 0: 384x640 1 car, 30.9ms
# Speed: 2.5ms preprocess, 30.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(242, 169, 316, 208)
# Detected car: ID=12, BBox=(375, 230, 474, 271)
# [(242, 169, 316, 208, '10'), (375, 230, 474, 271, '12')]
#
# 0: 384x640 1 car, 34.7ms
# Speed: 3.4ms preprocess, 34.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(243, 169, 317, 208)
# Detected car: ID=12, BBox=(380, 225, 484, 269)
# [(243, 169, 317, 208, '10'), (380, 225, 484, 269, '12')]
#
# 0: 384x640 2 cars, 30.5ms
# Speed: 2.8ms preprocess, 30.5ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(243, 169, 316, 207)
# Detected car: ID=12, BBox=(388, 223, 492, 267)
# [(243, 169, 316, 207, '10'), (388, 223, 492, 267, '12')]
#
# 0: 384x640 1 car, 29.9ms
# Speed: 3.0ms preprocess, 29.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(244, 169, 316, 207)
# Detected car: ID=12, BBox=(396, 222, 499, 266)
# [(244, 169, 316, 207, '10'), (396, 222, 499, 266, '12')]
#
# 0: 384x640 2 cars, 29.0ms
# Speed: 2.8ms preprocess, 29.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(246, 169, 319, 207)
# Detected car: ID=12, BBox=(405, 220, 506, 264)
# [(246, 169, 319, 207, '10'), (405, 220, 506, 264, '12')]
#
# 0: 384x640 1 car, 29.8ms
# Speed: 2.6ms preprocess, 29.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(247, 169, 320, 206)
# Detected car: ID=12, BBox=(412, 218, 514, 262)
# [(247, 169, 320, 206, '10'), (412, 218, 514, 262, '12')]
#
# 0: 384x640 1 car, 29.8ms
# Speed: 2.7ms preprocess, 29.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(246, 169, 322, 206)
# Detected car: ID=12, BBox=(420, 216, 523, 261)
# [(246, 169, 322, 206, '10'), (420, 216, 523, 261, '12')]
#
# 0: 384x640 1 car, 1 truck, 30.1ms
# Speed: 2.7ms preprocess, 30.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected car: ID=10, BBox=(246, 169, 323, 206)
# Detected car: ID=12, BBox=(428, 214, 531, 259)
# [(246, 169, 323, 206, '10'), (428, 214, 531, 259, '12')]

# %%
# Convert the .avi video generated by the YOLOv8 prediction to .mp4 format for compatibility with notebook display
# !ffmpeg -y -loglevel panic -i result_video.avi result_video.mp4
Video('result_video.mp4', embed=True, width=960)
# Out:
# <video controls  width="960" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# !python --version
# Out:
# Python 3.10.13
